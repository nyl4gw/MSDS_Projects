# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# '/Users/nicholaslandi/Desktop/DataVizCode'

# %%
pd.set_option('display.max_columns', None)
meat_consumption = pd.read_csv('meat_consumption.csv')  
meat_consumption
# Out:
#       LOCATION SUBJECT     MEASURE  TIME       Value
# 0          AUS    BEEF      KG_CAP  1990    0.000004
# 1          AUS    BEEF      KG_CAP  1991   27.808401
# 2          AUS    BEEF      KG_CAP  1992   26.278166
# 3          AUS    BEEF      KG_CAP  1993   26.244478
# 4          AUS    BEEF      KG_CAP  1994   25.541244
# ...        ...     ...         ...   ...         ...
# 12135     EU27   SHEEP  THND_TONNE  2024  732.149998
# 12136     EU27   SHEEP  THND_TONNE  2025  737.008238
# 12137     EU27   SHEEP  THND_TONNE  2026  741.104095
# 12138     EU27   SHEEP  THND_TONNE  2027  743.489549
# 12139     EU27   SHEEP  THND_TONNE  2028  747.011872
#
# [12140 rows x 5 columns]

# %% [markdown]
# ## WORKING WITH COUNTRY_POP

# %%
country_pop = pd.read_excel('Country-Population.xls')  
country_pop.head() #subset only relevant columns, convert to long format and combine with KG_CAP table
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54208.0
# 1      Andorra          AND  Population, total    SP.POP.TOTL    13414.0
# 2  Afghanistan          AFG  Population, total    SP.POP.TOTL  8994793.0
# 3       Angola          AGO  Population, total    SP.POP.TOTL  5270844.0
# 4      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
#
#         1961       1962       1963       1964       1965        1966  \
# 0    55435.0    56226.0    56697.0    57029.0    57360.0     57712.0
# 1    14376.0    15376.0    16410.0    17470.0    18551.0     19646.0
# 2  9164945.0  9343772.0  9531555.0  9728645.0  9935358.0  10148841.0
# 3  5367287.0  5465905.0  5565808.0  5665701.0  5765025.0   5863568.0
# 4  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0   1914573.0
#
#          1967        1968        1969        1970        1971        1972  \
# ...

# %%
country_pop.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013'],
#       dtype='object')

# %%
#filter out rows with THND_TONNE as default measure 
KG_CAP = meat_consumption.loc[meat_consumption['MEASURE'] == 'KG_CAP'].reset_index().drop(['index'], axis=1)
KG_CAP
# Out:
#      LOCATION SUBJECT MEASURE  TIME      Value
# 0         AUS    BEEF  KG_CAP  1990   0.000004
# 1         AUS    BEEF  KG_CAP  1991  27.808401
# 2         AUS    BEEF  KG_CAP  1992  26.278166
# 3         AUS    BEEF  KG_CAP  1993  26.244478
# 4         AUS    BEEF  KG_CAP  1994  25.541244
# ...       ...     ...     ...   ...        ...
# 6051      GBR   SHEEP  KG_CAP  2024   4.119413
# 6052      GBR   SHEEP  KG_CAP  2025   4.123996
# 6053      GBR   SHEEP  KG_CAP  2026   4.125127
# 6054      GBR   SHEEP  KG_CAP  2027   4.135186
# 6055      GBR   SHEEP  KG_CAP  2028   4.145831
#
# [6056 rows x 5 columns]

# %%
KG_CAP.TIME.unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022,
#        2023, 2024, 2025, 2026, 2027, 2028])

# %%
#remove EU27, OECD, BRICS, 'WLD'
#define values
values = ['EU27', 'OECD', 'BRICS', 'WLD']

#drop rows that contain any value in the list
KG_CAP = KG_CAP[KG_CAP.LOCATION.isin(values) == False]

# %%
KG_CAP = KG_CAP.reset_index().drop(['index'], axis=1)
KG_CAP
# Out:
#      LOCATION SUBJECT MEASURE  TIME      Value
# 0         AUS    BEEF  KG_CAP  1990   0.000004
# 1         AUS    BEEF  KG_CAP  1991  27.808401
# 2         AUS    BEEF  KG_CAP  1992  26.278166
# 3         AUS    BEEF  KG_CAP  1993  26.244478
# 4         AUS    BEEF  KG_CAP  1994  25.541244
# ...       ...     ...     ...   ...        ...
# 5427      GBR   SHEEP  KG_CAP  2024   4.119413
# 5428      GBR   SHEEP  KG_CAP  2025   4.123996
# 5429      GBR   SHEEP  KG_CAP  2026   4.125127
# 5430      GBR   SHEEP  KG_CAP  2027   4.135186
# 5431      GBR   SHEEP  KG_CAP  2028   4.145831
#
# [5432 rows x 5 columns]

# %%
KG_CAP.LOCATION.unique()
# Out:
# array(['AUS', 'CAN', 'JPN', 'KOR', 'MEX', 'NZL', 'TUR', 'USA', 'ARG',
#        'BRA', 'CHL', 'CHN', 'COL', 'EGY', 'ETH', 'IND', 'IDN', 'IRN',
#        'ISR', 'KAZ', 'MYS', 'NGA', 'PAK', 'PRY', 'PER', 'PHL', 'RUS',
#        'SAU', 'ZAF', 'THA', 'UKR', 'VNM', 'NOR', 'CHE', 'GBR'],
#       dtype=object)

# %%
values2 = ['AUS', 'CAN', 'JPN', 'KOR', 'MEX', 'NZL', 'TUR', 'USA', 'ARG',
       'BRA', 'CHL', 'CHN', 'COL', 'EGY', 'ETH', 'IND', 'IDN', 'IRN',
       'ISR', 'KAZ', 'MYS', 'NGA', 'PAK', 'PRY', 'PER', 'PHL', 'RUS',
       'SAU', 'ZAF', 'THA', 'UKR', 'VNM', 'WLD', 'NOR', 'CHE', 'GBR']

# %%
country_pop = country_pop[country_pop['Country Code'].isin(values2) == True]

# %%
country_pop.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013'],
#       dtype='object')

# %%
country_pop = country_pop.reset_index().drop(['index'], axis=1)
#drop uncessary columns (ie 1960-1989)
country_pop = country_pop.drop(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989'], axis=1)
country_pop.head()
#reformat
# Out:
#   Country Name Country Code     Indicator Name Indicator Code         1990  \
# 0    Argentina          ARG  Population, total    SP.POP.TOTL   32729740.0
# 1    Australia          AUS  Population, total    SP.POP.TOTL   17065100.0
# 2       Brazil          BRA  Population, total    SP.POP.TOTL  150393143.0
# 3       Canada          CAN  Population, total    SP.POP.TOTL   27791000.0
# 4  Switzerland          CHE  Population, total    SP.POP.TOTL    6715519.0
#
#           1991         1992         1993         1994         1995  \
# 0   33193920.0   33655149.0   34110912.0   34558114.0   34994818.0
# 1   17284000.0   17495000.0   17667000.0   17855000.0   18072000.0
# 2  152916852.0  155379009.0  157812220.0  160260508.0  162755054.0
# 3   28171682.0   28519597.0   28833410.0   29111906.0   29354000.0
# 4    6799978.0    6875364.0    6938265.0    6993795.0    7040687.0
#
#           1996         1997         1998         1999         2000  \
# ...

# %%
#melt country_pop
country_pop_clean = pd.melt(country_pop, id_vars = ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], 
        value_vars = [str(i) for i in range(1990,2014)])
country_pop_clean = country_pop_clean.rename({'variable':'Year', 'value':'Population'}, axis=1)
country_pop_clean = country_pop_clean.sort_values(by =['Country Code', 'Year']).reset_index().drop(['index'], axis=1)
country_pop_clean #convert to clean CSV
# Out:
#      Country Name Country Code     Indicator Name Indicator Code  Year  \
# 0       Argentina          ARG  Population, total    SP.POP.TOTL  1990
# 1       Argentina          ARG  Population, total    SP.POP.TOTL  1991
# 2       Argentina          ARG  Population, total    SP.POP.TOTL  1992
# 3       Argentina          ARG  Population, total    SP.POP.TOTL  1993
# 4       Argentina          ARG  Population, total    SP.POP.TOTL  1994
# ..            ...          ...                ...            ...   ...
# 835  South Africa          ZAF  Population, total    SP.POP.TOTL  2009
# 836  South Africa          ZAF  Population, total    SP.POP.TOTL  2010
# 837  South Africa          ZAF  Population, total    SP.POP.TOTL  2011
# 838  South Africa          ZAF  Population, total    SP.POP.TOTL  2012
# 839  South Africa          ZAF  Population, total    SP.POP.TOTL  2013
#
#      Population
# 0    32729740.0
# 1    33193920.0
# 2    33655149.0
# 3    34110912.0
# 4    34558114.0
# ...

# %%
country_pop_clean.to_csv('/Users/nicholaslandi/Desktop/DataVizCode/country_pop_clean.csv', index=False)

# %%
#country_pop_clean[country_pop_clean['Country Code'] == 'ARG']

# %% [markdown]
# ## WORKING WITH COUNTRY GDP

# %%
GDP = pd.read_csv('GDP.csv')
GDP.head() #subset only relevant columns, convert to long format and combine with KG_CAP table
# Out:
#       Country  Country Code          1990          1991          1992  \
# 0        Aruba          ABW  24101.109430  25870.755940  26533.343900
# 1  Afghanistan          AFG           NaN           NaN           NaN
# 2       Angola          AGO   3089.683369   3120.356148   2908.160798
# 3      Albania          ALB   2549.473022   1909.114038   1823.307673
# 4   Arab World          ARB   6808.206995   6872.273195   7255.328362
#
#            1993          1994          1995          1996          1997  \
# 0  27430.752400  28656.520210  28648.990020  28499.089430  30215.949230
# 1           NaN           NaN           NaN           NaN           NaN
# 2   2190.768160   2195.532289   2496.199493   2794.896906   2953.342709
# 3   2057.449657   2289.873135   2665.764906   2980.066288   2717.362124
# 4   7458.647059   7645.682856   7774.207360   8094.149842   8397.515692
#
#            1998          1999          2000          2001          2002  \
# ...

# %%
GDP = GDP[GDP['Country Code'].isin(values2) == True]
GDP = GDP.drop(['2019'], axis=1)
GDP.head()
# Out:
#        Country  Country Code          1990          1991          1992  \
# 6     Argentina          ARG   7380.115031   8210.643432   8942.569853
# 9     Australia          AUS  17329.706610  17790.980140  18189.378740
# 25       Brazil          BRA   6710.964526   6919.981067   6925.379871
# 31       Canada          CAN  20173.935650  20160.728850  20557.463360
# 33  Switzerland          CHE  27594.632050  27915.471560  28226.226740
#
#             1993          1994         1995          1996          1997  \
# 6    9777.214005  10435.910770  10225.11871  10857.429670  11802.842590
# 9   19131.841870  20064.459010  20894.39721  21972.052650  22934.786010
# 25   7297.683777   7723.899622   8102.66855   8300.244709   8594.561343
# 31  21367.203270  22555.697440  23401.87468  23962.499450  25167.519710
# 33  28596.952840  29343.631580  29902.51870  30542.057430  31812.498760
#
#             1998          1999          2000         2001          2002  \
# ...

# %%
GDP.columns
# Out:
# Index(['Country ', 'Country Code', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018'],
#       dtype='object')

# %%
#melt GDP
GDP_clean = pd.melt(GDP, id_vars = ['Country ', 'Country Code'], 
        value_vars = [str(i) for i in range(1990,2019)])
GDP_clean
# Out:
#            Country  Country Code variable         value
# 0         Argentina          ARG     1990   7380.115031
# 1         Australia          AUS     1990  17329.706610
# 2            Brazil          BRA     1990   6710.964526
# 3            Canada          CAN     1990  20173.935650
# 4       Switzerland          CHE     1990  27594.632050
# ...             ...          ...      ...           ...
# 1039        Ukraine          UKR     2018   9249.462135
# 1040  United States          USA     2018  62794.585650
# 1041        Vietnam          VNM     2018   7447.814334
# 1042          World          WLD     2018  17948.417040
# 1043   South Africa          ZAF     2018  13686.882360
#
# [1044 rows x 4 columns]

# %%
GDP_clean = GDP_clean.rename({'Country ': 'Country Name', 'variable':'Year', 'value':'GDP per Capita PPP'}, axis=1)
GDP_clean = GDP_clean.sort_values(by =['Country Code', 'Year']).reset_index().drop(['index'], axis=1)
GDP_clean
# Out:
#       Country Name Country Code  Year  GDP per Capita PPP
# 0        Argentina          ARG  1990         7380.115031
# 1        Argentina          ARG  1991         8210.643432
# 2        Argentina          ARG  1992         8942.569853
# 3        Argentina          ARG  1993         9777.214005
# 4        Argentina          ARG  1994        10435.910770
# ...            ...          ...   ...                 ...
# 1039  South Africa          ZAF  2014        13090.476830
# 1040  South Africa          ZAF  2015        13185.253280
# 1041  South Africa          ZAF  2016        13188.029620
# 1042  South Africa          ZAF  2017        13438.282890
# 1043  South Africa          ZAF  2018        13686.882360
#
# [1044 rows x 4 columns]

# %%
#remove rows where COUNTRY CODE = WLD 
WLD = ['WLD']

# %%
GDP_clean = GDP_clean[GDP_clean['Country Code'].isin(WLD) == False]

# %%
GDP_clean = GDP_clean.reset_index().drop(['index'], axis=1)
GDP_clean
# Out:
#       Country Name Country Code  Year  GDP per Capita PPP
# 0        Argentina          ARG  1990         7380.115031
# 1        Argentina          ARG  1991         8210.643432
# 2        Argentina          ARG  1992         8942.569853
# 3        Argentina          ARG  1993         9777.214005
# 4        Argentina          ARG  1994        10435.910770
# ...            ...          ...   ...                 ...
# 1010  South Africa          ZAF  2014        13090.476830
# 1011  South Africa          ZAF  2015        13185.253280
# 1012  South Africa          ZAF  2016        13188.029620
# 1013  South Africa          ZAF  2017        13438.282890
# 1014  South Africa          ZAF  2018        13686.882360
#
# [1015 rows x 4 columns]

# %%
GDP_clean['Country Code'].unique()
# Out:
# array(['ARG', 'AUS', 'BRA', 'CAN', 'CHE', 'CHL', 'CHN', 'COL', 'EGY',
#        'ETH', 'GBR', 'IDN', 'IND', 'IRN', 'ISR', 'JPN', 'KAZ', 'KOR',
#        'MEX', 'MYS', 'NGA', 'NOR', 'NZL', 'PAK', 'PER', 'PHL', 'PRY',
#        'RUS', 'SAU', 'THA', 'TUR', 'UKR', 'USA', 'VNM', 'ZAF'],
#       dtype=object)

# %%
#GDP_clean.to_csv('/Users/nicholaslandi/Desktop/DataVizCode/GDP_clean.csv', index=False)  #convert to clean CSV

# %%
#print(len(country_pop))
#print(len(KG_CAP.LOCATION.unique()))

# %%
#country_pop['Country Code'].unique()

# %%
#KG_CAP.LOCATION.unique()

# %%
#KG_CAP.groupby('LOCATION')['Value'].mean().sort_values(ascending=False)
#need to account for EU27, BRICS, OECD

# %%
#KG_CAP['LOCATION'].value_counts()

# %%
#KG_CAP['SUBJECT'].value_counts()

# %%
KG_CAP.dtypes
# Out:
# LOCATION     object
# SUBJECT      object
# MEASURE      object
# TIME          int64
# Value       float64
# dtype: object

# %%
KG_CAP['TIME'] = KG_CAP['TIME'].astype(str)

# %%
KG_CAP.dtypes
# Out:
# LOCATION     object
# SUBJECT      object
# MEASURE      object
# TIME         object
# Value       float64
# dtype: object

# %%
KG_CAP.head()
# Out:
#   LOCATION SUBJECT MEASURE  TIME      Value
# 0      AUS    BEEF  KG_CAP  1990   0.000004
# 1      AUS    BEEF  KG_CAP  1991  27.808401
# 2      AUS    BEEF  KG_CAP  1992  26.278166
# 3      AUS    BEEF  KG_CAP  1993  26.244478
# 4      AUS    BEEF  KG_CAP  1994  25.541244

# %%
KG_CAP = KG_CAP.rename({'LOCATION':'Country Code', 'SUBJECT':'Meat_Type', 'TIME':'Year','Value':'KG_Consumer_Per_Capita'}, axis=1)
KG_CAP = KG_CAP.drop(['MEASURE'], axis=1)
KG_CAP.head()
# Out:
#   Country Code Meat_Type  Year  KG_Consumer_Per_Capita
# 0          AUS      BEEF  1990                0.000004
# 1          AUS      BEEF  1991               27.808401
# 2          AUS      BEEF  1992               26.278166
# 3          AUS      BEEF  1993               26.244478
# 4          AUS      BEEF  1994               25.541244

# %%
KG_CAP.to_csv('/Users/nicholaslandi/Desktop/DataVizCode/meat_consumption_processed.csv', index=False)

# %%
KG_CAP['Year'].unique()
# Out:
# array(['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        '2022', '2023', '2024', '2025', '2026', '2027', '2028'],
#       dtype=object)

# %%
country_pop_clean.head()
country_pop_clean['Year'].unique()
# Out:
# array(['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013'],
#       dtype=object)

# %%
GDP_clean.head()
GDP_clean['Year'].unique()
# Out:
# array(['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018'], dtype=object)

# %%
#subset each data set so they only go to 2013

invalid_years = ['2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
       '2022', '2023', '2024', '2025', '2026', '2027', '2028']

#drop rows that contain any value in the list
KG_CAP = KG_CAP[KG_CAP.Year.isin(invalid_years) == False].reset_index().drop(['index'], axis=1)

GDP_clean = GDP_clean[GDP_clean.Year.isin(invalid_years) == False].reset_index().drop(['index'], axis=1)

# %%
merged_data = pd.merge(KG_CAP, country_pop_clean, on=['Country Code', 'Year'], how = 'left')
merged_data
# Out:
#      Country Code Meat_Type  Year  KG_Consumer_Per_Capita    Country Name  \
# 0             AUS      BEEF  1990                0.000004       Australia
# 1             AUS      BEEF  1991               27.808401       Australia
# 2             AUS      BEEF  1992               26.278166       Australia
# 3             AUS      BEEF  1993               26.244478       Australia
# 4             AUS      BEEF  1994               25.541244       Australia
# ...           ...       ...   ...                     ...             ...
# 3327          GBR     SHEEP  2009                4.915320  United Kingdom
# 3328          GBR     SHEEP  2010                4.352106  United Kingdom
# 3329          GBR     SHEEP  2011                4.123211  United Kingdom
# 3330          GBR     SHEEP  2012                3.880044  United Kingdom
# 3331          GBR     SHEEP  2013                4.093783  United Kingdom
#
#          Indicator Name Indicator Code  Population
# ...

# %%
merged_data = pd.merge(merged_data, GDP_clean, on=['Country Code', 'Year'], how = 'left')
merged_data
# Out:
#      Country Code Meat_Type  Year  KG_Consumer_Per_Capita  Country Name_x  \
# 0             AUS      BEEF  1990                0.000004       Australia
# 1             AUS      BEEF  1991               27.808401       Australia
# 2             AUS      BEEF  1992               26.278166       Australia
# 3             AUS      BEEF  1993               26.244478       Australia
# 4             AUS      BEEF  1994               25.541244       Australia
# ...           ...       ...   ...                     ...             ...
# 3327          GBR     SHEEP  2009                4.915320  United Kingdom
# 3328          GBR     SHEEP  2010                4.352106  United Kingdom
# 3329          GBR     SHEEP  2011                4.123211  United Kingdom
# 3330          GBR     SHEEP  2012                3.880044  United Kingdom
# 3331          GBR     SHEEP  2013                4.093783  United Kingdom
#
#          Indicator Name Indicator Code  Population  Country Name_y  \
# ...

# %%
#merged_data.to_csv('/Users/nicholaslandi/Desktop/DataVizCode/meat_merged_final.csv', index=False)

# %% [markdown]
# ## Working with GHG Emissions

# %%
GHG = pd.read_csv('ghg-emissions.csv')
GHG.head() #subset only relevant columns, convert to long format and combine with KG_CAP table
# Out:
#   Country/Region    unit     1990     1991     1992     1993     1994  \
# 0          China  MtCO2e  2873.71  3023.38  3154.54  3377.79  3528.81
# 1  United States  MtCO2e  5543.47  5501.92  5583.80  5691.26  5782.20
# 2          India  MtCO2e  1009.44  1064.49  1096.71  1128.44  1174.78
# 3         Russia  MtCO2e  2885.12  2788.70  2551.94  2294.62  2011.47
# 4      Indonesia  MtCO2e  1257.10  1274.43  1295.01  1311.27  1327.87
#
#       1995     1996     1997     1998     1999     2000     2001     2002  \
# 0  3918.30  3954.75  3963.61  4103.23  4053.37  4249.70  4459.91  4769.03
# 1  5843.90  6010.62  6258.47  6293.80  6291.25  6446.20  6406.04  6246.95
# 2  1240.44  1289.63  1348.09  1382.26  1460.24  1498.20  1747.49  1769.79
# 3  1930.88  1889.18  1755.59  1740.23  1772.68  1831.09  1455.44  1477.17
# 4  1360.88  1179.00  2142.82  1373.56  1261.56  1191.82  1019.35  1500.98
#
#       2003     2004     2005     2006     2007     2008     2009     2010  \
# ...

# %%
GHG.unit.value_counts()
# Out:
# MtCO2e                                                                                                                            193
# Countries/Regions: World. Sectors/Subsectors: Total including LUCF. Gases: All GHG. Calculation: Total. Show data by Countries      1
# CAIT                                                                                                                                1
# Name: unit, dtype: int64

# %%
#subset MtCO2e rows
GHG = GHG.loc[GHG['unit'] == 'MtCO2e'].reset_index().drop(['index'], axis=1)
GHG
# Out:
#     Country/Region    unit     1990     1991     1992     1993     1994  \
# 0            China  MtCO2e  2873.71  3023.38  3154.54  3377.79  3528.81
# 1    United States  MtCO2e  5543.47  5501.92  5583.80  5691.26  5782.20
# 2            India  MtCO2e  1009.44  1064.49  1096.71  1128.44  1174.78
# 3           Russia  MtCO2e  2885.12  2788.70  2551.94  2294.62  2011.47
# 4        Indonesia  MtCO2e  1257.10  1274.43  1295.01  1311.27  1327.87
# ..             ...     ...      ...      ...      ...      ...      ...
# 188       Kiribati  MtCO2e     0.04     0.04     0.04     0.05     0.04
# 189   Cook Islands  MtCO2e     0.03     0.03     0.03     0.03     0.03
# 190          Nauru  MtCO2e     0.13     0.13     0.13     0.12     0.12
# 191         Tuvalu  MtCO2e     0.02     0.02     0.02     0.02     0.02
# 192           Niue  MtCO2e     0.01     0.01     0.01     0.01     0.01
#
#         1995     1996     1997     1998     1999     2000     2001     2002  \
# ...

# %%
#drop year columns 2014-2018
GHG = GHG.drop(['2014', '2015', '2016', '2017', '2018'], axis=1)
GHG.head()
# Out:
#   Country/Region    unit     1990     1991     1992     1993     1994  \
# 0          China  MtCO2e  2873.71  3023.38  3154.54  3377.79  3528.81
# 1  United States  MtCO2e  5543.47  5501.92  5583.80  5691.26  5782.20
# 2          India  MtCO2e  1009.44  1064.49  1096.71  1128.44  1174.78
# 3         Russia  MtCO2e  2885.12  2788.70  2551.94  2294.62  2011.47
# 4      Indonesia  MtCO2e  1257.10  1274.43  1295.01  1311.27  1327.87
#
#       1995     1996     1997     1998     1999     2000     2001     2002  \
# 0  3918.30  3954.75  3963.61  4103.23  4053.37  4249.70  4459.91  4769.03
# 1  5843.90  6010.62  6258.47  6293.80  6291.25  6446.20  6406.04  6246.95
# 2  1240.44  1289.63  1348.09  1382.26  1460.24  1498.20  1747.49  1769.79
# 3  1930.88  1889.18  1755.59  1740.23  1772.68  1831.09  1455.44  1477.17
# 4  1360.88  1179.00  2142.82  1373.56  1261.56  1191.82  1019.35  1500.98
#
#       2003     2004     2005     2006     2007     2008     2009     2010  \
# ...

# %%
#rename columns
GHG = GHG.rename({'Country/Region': 'Country Name', 'unit':'Unit'}, axis=1)

# %%
GHG.head()
# Out:
#     Country Name    Unit     1990     1991     1992     1993     1994  \
# 0          China  MtCO2e  2873.71  3023.38  3154.54  3377.79  3528.81
# 1  United States  MtCO2e  5543.47  5501.92  5583.80  5691.26  5782.20
# 2          India  MtCO2e  1009.44  1064.49  1096.71  1128.44  1174.78
# 3         Russia  MtCO2e  2885.12  2788.70  2551.94  2294.62  2011.47
# 4      Indonesia  MtCO2e  1257.10  1274.43  1295.01  1311.27  1327.87
#
#       1995     1996     1997     1998     1999     2000     2001     2002  \
# 0  3918.30  3954.75  3963.61  4103.23  4053.37  4249.70  4459.91  4769.03
# 1  5843.90  6010.62  6258.47  6293.80  6291.25  6446.20  6406.04  6246.95
# 2  1240.44  1289.63  1348.09  1382.26  1460.24  1498.20  1747.49  1769.79
# 3  1930.88  1889.18  1755.59  1740.23  1772.68  1831.09  1455.44  1477.17
# 4  1360.88  1179.00  2142.82  1373.56  1261.56  1191.82  1019.35  1500.98
#
#       2003     2004     2005     2006     2007     2008     2009     2010  \
# ...

# %%
GHG['Country Name'].unique()
# Out:
# array(['China', 'United States', 'India', 'Russia', 'Indonesia', 'Brazil',
#        'Japan', 'Iran', 'Germany', 'Canada', 'Mexico',
#        'Democratic Republic of the Congo', 'South Korea', 'Saudi Arabia',
#        'Australia', 'South Africa', 'Turkey', 'United Kingdom',
#        'Pakistan', 'Thailand', 'Argentina', 'Malaysia', 'Italy',
#        'Vietnam', 'France', 'Nigeria', 'Poland', 'Egypt', 'Spain',
#        'Venezuela', 'Kazakhstan', 'Colombia', 'United Arab Emirates',
#        'Ukraine', 'Philippines', 'Uzbekistan', 'Myanmar', 'Bangladesh',
#        'Algeria', 'Iraq', 'Ethiopia', 'Peru', 'Netherlands', 'Tanzania',
#        'Sudan', 'Bolivia', 'Turkmenistan', 'Angola', 'Cameroon',
#        'Zimbabwe', 'Czech Republic', 'Kuwait', 'Mozambique', 'Belgium',
#        'Chad', 'Libya', 'Qatar', 'Afghanistan', 'Paraguay', 'Zambia',
#        'Morocco', 'Ecuador', 'Israel', 'Central African Republic',
#        'Greece', 'Romania', 'Oman', 'Azerbaijan', 'Kenya', 'New Zealand',
# ...

# %%
merged_data['Country Name_x'].unique()
# Out:
# array(['Australia', 'Canada', 'Japan', 'Korea, Rep.', 'Mexico',
#        'New Zealand', 'Turkey', 'United States', 'Argentina', 'Brazil',
#        'Chile', 'China', 'Colombia', 'Egypt, Arab Rep.', 'Ethiopia',
#        'India', 'Indonesia', 'Iran, Islamic Rep.', 'Israel', 'Kazakhstan',
#        'Malaysia', 'Nigeria', 'Pakistan', 'Paraguay', 'Peru',
#        'Philippines', 'Russian Federation', 'Saudi Arabia',
#        'South Africa', 'Thailand', 'Ukraine', 'Vietnam', 'Norway',
#        'Switzerland', 'United Kingdom'], dtype=object)

# %%
GHG_countries = ['China', 'United States', 'India', 'Russia', 'Indonesia', 'Brazil',
       'Japan', 'Iran', 'Germany', 'Canada', 'Mexico',
       'Democratic Republic of the Congo', 'South Korea', 'Saudi Arabia',
       'Australia', 'South Africa', 'Turkey', 'United Kingdom',
       'Pakistan', 'Thailand', 'Argentina', 'Malaysia', 'Italy',
       'Vietnam', 'France', 'Nigeria', 'Poland', 'Egypt', 'Spain',
       'Venezuela', 'Kazakhstan', 'Colombia', 'United Arab Emirates',
       'Ukraine', 'Philippines', 'Uzbekistan', 'Myanmar', 'Bangladesh',
       'Algeria', 'Iraq', 'Ethiopia', 'Peru', 'Netherlands', 'Tanzania',
       'Sudan', 'Bolivia', 'Turkmenistan', 'Angola', 'Cameroon',
       'Zimbabwe', 'Czech Republic', 'Kuwait', 'Mozambique', 'Belgium',
       'Chad', 'Libya', 'Qatar', 'Afghanistan', 'Paraguay', 'Zambia',
       'Morocco', 'Ecuador', 'Israel', 'Central African Republic',
       'Greece', 'Romania', 'Oman', 'Azerbaijan', 'Kenya', 'New Zealand',
       'Uganda', 'Cambodia', 'South Sudan', 'Austria', 'Portugal',
       'Belarus', 'Singapore', 'Papua New Guinea', 'Hungary', 'Serbia',
       'Ireland', 'Finland', 'Botswana', 'Mongolia', 'Burkina Faso',
       'Nepal', 'Chile', "Côte d'Ivoire", 'Bahrain', 'Denmark',
       'Solomon Islands', 'Syria', 'Niger', 'North Korea', 'Somalia',
       'Switzerland', 'Mali', 'Madagascar', 'Guinea', 'Slovakia', 'Cuba',
       'Guatemala', 'Nicaragua', 'Laos', 'Dominican Republic', 'Tunisia',
       'Sri Lanka', 'Jordan', 'Uruguay', 'Senegal', 'Lebanon', 'Sweden',
       'Norway', 'Honduras', 'Benin', 'Malawi', 'Bosnia and Herzegovina',
       'Equatorial Guinea', 'Trinidad and Tobago', 'Liberia', 'Namibia',
       'Panama', 'Yemen', 'Estonia', 'Republic of Congo', 'Ghana',
       'Bulgaria', 'Guyana', 'Lithuania', 'Croatia', 'Slovenia', 'Brunei',
       'Georgia', 'Tajikistan', 'Kyrgyzstan', 'Gabon', 'El Salvador',
       'Moldova', 'Suriname', 'Mauritania', 'Sierra Leone', 'Haiti',
       'Macedonia', 'Jamaica', 'Luxembourg', 'Albania', 'Armenia', 'Togo',
       'Burundi', 'Latvia', 'Costa Rica', 'Cyprus', 'Eritrea', 'Rwanda',
       'Belize', 'Mauritius', 'Timor-Leste', 'Lesotho', 'Guinea-Bissau',
       'Montenegro', 'Barbados', 'Iceland', 'Gambia', 'Eswatini',
       'Bahamas', 'Maldives', 'Grenada', 'Malta', 'Djibouti',
       'Antigua and Barbuda', 'Bhutan', 'Vanuatu', 'Samoa', 'Seychelles',
       'Cape Verde', 'Comoros', 'Saint Lucia', 'Andorra',
       'Sao Tome and Principe', 'Saint Kitts and Nevis',
       'Saint Vincent and the Grenadines', 'Tonga', 'Palau', 'Fiji',
       'Micronesia', 'Marshall Islands', 'Dominica', 'Liechtenstein',
       'Kiribati', 'Cook Islands', 'Nauru', 'Tuvalu', 'Niue']

# %%
merged_countries = ['Australia', 'Canada', 'Japan', 'Korea, Rep.', 'Mexico',
       'New Zealand', 'Turkey', 'United States', 'Argentina', 'Brazil',
       'Chile', 'China', 'Colombia', 'Egypt, Arab Rep.', 'Ethiopia',
       'India', 'Indonesia', 'Iran, Islamic Rep.', 'Israel', 'Kazakhstan',
       'Malaysia', 'Nigeria', 'Pakistan', 'Paraguay', 'Peru',
       'Philippines', 'Russian Federation', 'Saudi Arabia',
       'South Africa', 'Thailand', 'Ukraine', 'Vietnam', 'Norway',
       'Switzerland', 'United Kingdom']

# %%
#check to see which ones need to be renamed 
for i in merged_countries:
    if i not in GHG_countries:
        print(i)
# Out:
# Korea, Rep.
# Egypt, Arab Rep.
# Iran, Islamic Rep.
# Russian Federation

# %%
#replace row values in GHG 
GHG['Country Name'] = GHG['Country Name'].replace({'South Korea':'Korea, Rep.', 'Egypt':'Egypt, Arab Rep.', 'Iran':'Iran, Islamic Rep.', 'Russia':'Russian Federation'})

# %%
GHG = GHG[GHG['Country Name'].isin(merged_countries) == True]

# %%
print(len(GHG['Country Name'].unique()))
print(len(merged_data['Country Code'].unique()))
# Out:
# 35
# 35

# %%
GHG = GHG.reset_index().drop(['index'], axis=1)
GHG
# Out:
#           Country Name    Unit     1990     1991     1992     1993     1994  \
# 0                China  MtCO2e  2873.71  3023.38  3154.54  3377.79  3528.81
# 1        United States  MtCO2e  5543.47  5501.92  5583.80  5691.26  5782.20
# 2                India  MtCO2e  1009.44  1064.49  1096.71  1128.44  1174.78
# 3   Russian Federation  MtCO2e  2885.12  2788.70  2551.94  2294.62  2011.47
# 4            Indonesia  MtCO2e  1257.10  1274.43  1295.01  1311.27  1327.87
# 5               Brazil  MtCO2e  1642.29  1669.56  1679.50  1689.70  1706.03
# 6                Japan  MtCO2e  1109.37  1123.86  1137.15  1129.63  1186.79
# 7   Iran, Islamic Rep.  MtCO2e   240.54   280.88   301.84   300.14   332.67
# 8               Canada  MtCO2e   626.36   622.29   638.22   636.25   656.82
# 9               Mexico  MtCO2e   417.45   435.45   438.32   458.00   483.60
# 10         Korea, Rep.  MtCO2e   244.25   269.59   294.15   325.01   352.61
# ...

# %%
#melt GHG
GHG = pd.melt(GHG, id_vars = ['Country Name', 'Unit'], 
        value_vars = [str(i) for i in range(1990,2014)])
GHG
# Out:
#            Country Name    Unit variable    value
# 0                 China  MtCO2e     1990  2873.71
# 1         United States  MtCO2e     1990  5543.47
# 2                 India  MtCO2e     1990  1009.44
# 3    Russian Federation  MtCO2e     1990  2885.12
# 4             Indonesia  MtCO2e     1990  1257.10
# ..                  ...     ...      ...      ...
# 835              Israel  MtCO2e     2013    88.51
# 836         New Zealand  MtCO2e     2013    64.53
# 837               Chile  MtCO2e     2013    23.68
# 838         Switzerland  MtCO2e     2013    50.06
# 839              Norway  MtCO2e     2013    29.11
#
# [840 rows x 4 columns]

# %%
GHG = GHG.rename({'Country Name': 'Country Name', 'variable':'Year', 'value':'MtCO2e'}, axis=1)
GHG = GHG.sort_values(by =['Country Name', 'Year']).reset_index().drop(['index', 'Unit'], axis=1)
GHG
# Out:
#     Country Name  Year  MtCO2e
# 0      Argentina  1990  288.37
# 1      Argentina  1991  293.36
# 2      Argentina  1992  297.76
# 3      Argentina  1993  300.27
# 4      Argentina  1994  305.35
# ..           ...   ...     ...
# 835      Vietnam  2009  259.62
# 836      Vietnam  2010  277.74
# 837      Vietnam  2011  235.82
# 838      Vietnam  2012  236.38
# 839      Vietnam  2013  248.78
#
# [840 rows x 3 columns]

# %%
merged_data.head()
# Out:
#   Country Code Meat_Type  Year  KG_Consumer_Per_Capita Country Name_x  \
# 0          AUS      BEEF  1990                0.000004      Australia
# 1          AUS      BEEF  1991               27.808401      Australia
# 2          AUS      BEEF  1992               26.278166      Australia
# 3          AUS      BEEF  1993               26.244478      Australia
# 4          AUS      BEEF  1994               25.541244      Australia
#
#       Indicator Name Indicator Code  Population Country Name_y  \
# 0  Population, total    SP.POP.TOTL  17065100.0      Australia
# 1  Population, total    SP.POP.TOTL  17284000.0      Australia
# 2  Population, total    SP.POP.TOTL  17495000.0      Australia
# 3  Population, total    SP.POP.TOTL  17667000.0      Australia
# 4  Population, total    SP.POP.TOTL  17855000.0      Australia
#
#    GDP per Capita PPP
# 0         17329.70661
# 1         17790.98014
# 2         18189.37874
# 3         19131.84187
# 4         20064.45901

# %%
merged_data = merged_data.drop(['Country Name_y'], axis=1)
merged_data
# Out:
#      Country Code Meat_Type  Year  KG_Consumer_Per_Capita  Country Name_x  \
# 0             AUS      BEEF  1990                0.000004       Australia
# 1             AUS      BEEF  1991               27.808401       Australia
# 2             AUS      BEEF  1992               26.278166       Australia
# 3             AUS      BEEF  1993               26.244478       Australia
# 4             AUS      BEEF  1994               25.541244       Australia
# ...           ...       ...   ...                     ...             ...
# 3327          GBR     SHEEP  2009                4.915320  United Kingdom
# 3328          GBR     SHEEP  2010                4.352106  United Kingdom
# 3329          GBR     SHEEP  2011                4.123211  United Kingdom
# 3330          GBR     SHEEP  2012                3.880044  United Kingdom
# 3331          GBR     SHEEP  2013                4.093783  United Kingdom
#
#          Indicator Name Indicator Code  Population  GDP per Capita PPP
# ...

# %%
merged_data = merged_data.rename({'Country Name_x': 'Country Name'}, axis=1)
merged_data
# Out:
#      Country Code Meat_Type  Year  KG_Consumer_Per_Capita    Country Name  \
# 0             AUS      BEEF  1990                0.000004       Australia
# 1             AUS      BEEF  1991               27.808401       Australia
# 2             AUS      BEEF  1992               26.278166       Australia
# 3             AUS      BEEF  1993               26.244478       Australia
# 4             AUS      BEEF  1994               25.541244       Australia
# ...           ...       ...   ...                     ...             ...
# 3327          GBR     SHEEP  2009                4.915320  United Kingdom
# 3328          GBR     SHEEP  2010                4.352106  United Kingdom
# 3329          GBR     SHEEP  2011                4.123211  United Kingdom
# 3330          GBR     SHEEP  2012                3.880044  United Kingdom
# 3331          GBR     SHEEP  2013                4.093783  United Kingdom
#
#          Indicator Name Indicator Code  Population  GDP per Capita PPP
# ...

# %%
merged_data = pd.merge(merged_data, GHG, on=['Country Name', 'Year'], how = 'left')
merged_data
# Out:
#      Country Code Meat_Type  Year  KG_Consumer_Per_Capita    Country Name  \
# 0             AUS      BEEF  1990                0.000004       Australia
# 1             AUS      BEEF  1991               27.808401       Australia
# 2             AUS      BEEF  1992               26.278166       Australia
# 3             AUS      BEEF  1993               26.244478       Australia
# 4             AUS      BEEF  1994               25.541244       Australia
# ...           ...       ...   ...                     ...             ...
# 3327          GBR     SHEEP  2009                4.915320  United Kingdom
# 3328          GBR     SHEEP  2010                4.352106  United Kingdom
# 3329          GBR     SHEEP  2011                4.123211  United Kingdom
# 3330          GBR     SHEEP  2012                3.880044  United Kingdom
# 3331          GBR     SHEEP  2013                4.093783  United Kingdom
#
#          Indicator Name Indicator Code  Population  GDP per Capita PPP  MtCO2e
# ...

# %%
merged_data.columns
# Out:
# Index(['Country Code', 'Meat_Type', 'Year', 'KG_Consumer_Per_Capita',
#        'Country Name', 'Indicator Name', 'Indicator Code', 'Population',
#        'GDP per Capita PPP', 'MtCO2e'],
#       dtype='object')

# %%
merged_data = merged_data.drop(['Indicator Name', 'Indicator Code'], axis=1)
merged_data
# Out:
#      Country Code Meat_Type  Year  KG_Consumer_Per_Capita    Country Name  \
# 0             AUS      BEEF  1990                0.000004       Australia
# 1             AUS      BEEF  1991               27.808401       Australia
# 2             AUS      BEEF  1992               26.278166       Australia
# 3             AUS      BEEF  1993               26.244478       Australia
# 4             AUS      BEEF  1994               25.541244       Australia
# ...           ...       ...   ...                     ...             ...
# 3327          GBR     SHEEP  2009                4.915320  United Kingdom
# 3328          GBR     SHEEP  2010                4.352106  United Kingdom
# 3329          GBR     SHEEP  2011                4.123211  United Kingdom
# 3330          GBR     SHEEP  2012                3.880044  United Kingdom
# 3331          GBR     SHEEP  2013                4.093783  United Kingdom
#
#       Population  GDP per Capita PPP  MtCO2e
# ...

# %%
#merged_data.to_csv('/Users/nicholaslandi/Desktop/DataVizCode/meat_merged_emission.csv', index=False)

# %% [markdown]
# ## WORKING WITH LIFE EXPECTANCY

# %%
LIFE = pd.read_csv('life_expectancy.csv')
LIFE.head() #subset only relevant columns, convert to long format and combine with KG_CAP table
# Out:
#   Country Name Country Code                           Indicator Name  \
# 0        Aruba          ABW  Life expectancy at birth, total (years)
# 1  Afghanistan          AFG  Life expectancy at birth, total (years)
# 2       Angola          AGO  Life expectancy at birth, total (years)
# 3      Albania          ALB  Life expectancy at birth, total (years)
# 4      Andorra          AND  Life expectancy at birth, total (years)
#
#    Indicator Code    1960    1961    1962    1963    1964    1965    1966  \
# 0  SP.DYN.LE00.IN  65.662  66.074  66.444  66.787  67.113  67.435  67.762
# 1  SP.DYN.LE00.IN  32.292  32.742  33.185  33.624  34.060  34.495  34.928
# 2  SP.DYN.LE00.IN  33.251  33.573  33.914  34.272  34.645  35.031  35.426
# 3  SP.DYN.LE00.IN  62.279  63.298  64.187  64.911  65.461  65.848  66.108
# 4  SP.DYN.LE00.IN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#      1967    1968    1969    1970    1971    1972    1973    1974    1975  \
# ...

# %%
LIFE.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016'],
#       dtype='object')

# %%
#drop year columns
LIFE = LIFE.drop(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '2014', '2015', '2016'], axis=1)
LIFE.head()
# Out:
#   Country Name Country Code                           Indicator Name  \
# 0        Aruba          ABW  Life expectancy at birth, total (years)
# 1  Afghanistan          AFG  Life expectancy at birth, total (years)
# 2       Angola          AGO  Life expectancy at birth, total (years)
# 3      Albania          ALB  Life expectancy at birth, total (years)
# 4      Andorra          AND  Life expectancy at birth, total (years)
#
#    Indicator Code    1990    1991    1992    1993    1994    1995    1996  \
# 0  SP.DYN.LE00.IN  73.468  73.509  73.544  73.573  73.598  73.622  73.646
# 1  SP.DYN.LE00.IN  49.856  50.627  51.331  51.968  52.539  53.055  53.533
# 2  SP.DYN.LE00.IN  41.696  41.855  42.060  42.329  42.677  43.125  43.695
# 3  SP.DYN.LE00.IN  71.836  71.803  71.802  71.860  71.992  72.205  72.495
# 4  SP.DYN.LE00.IN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#      1997    1998    1999    2000    2001    2002    2003    2004    2005  \
# ...

# %%
LIFE['Country Code'].unique()
# Out:
# array(['ABW', 'AFG', 'AGO', 'ALB', 'AND', 'ARB', 'ARE', 'ARG', 'ARM',
#        'ASM', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA',
#        'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU', 'BOL',
#        'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CEB', 'CHE',
#        'CHI', 'CHL', 'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COL', 'COM',
#        'CPV', 'CRI', 'CSS', 'CUB', 'CUW', 'CYM', 'CYP', 'CZE', 'DEU',
#        'DJI', 'DMA', 'DNK', 'DOM', 'DZA', 'EAP', 'EAR', 'EAS', 'ECA',
#        'ECS', 'ECU', 'EGY', 'EMU', 'ERI', 'ESP', 'EST', 'ETH', 'EUU',
#        'FCS', 'FIN', 'FJI', 'FRA', 'FRO', 'FSM', 'GAB', 'GBR', 'GEO',
#        'GHA', 'GIB', 'GIN', 'GMB', 'GNB', 'GNQ', 'GRC', 'GRD', 'GRL',
#        'GTM', 'GUM', 'GUY', 'HIC', 'HKG', 'HND', 'HPC', 'HRV', 'HTI',
#        'HUN', 'IBD', 'IBT', 'IDA', 'IDB', 'IDN', 'IDX', 'IMN', 'IND',
#        'INX', 'IRL', 'IRN', 'IRQ', 'ISL', 'ISR', 'ITA', 'JAM', 'JOR',
# ...

# %%
values2 = list(merged_data['Country Code'].unique())
values2
# Out:
# ['AUS',
#  'CAN',
#  'JPN',
#  'KOR',
#  'MEX',
#  'NZL',
#  'TUR',
#  'USA',
#  'ARG',
#  'BRA',
#  'CHL',
#  'CHN',
#  'COL',
#  'EGY',
#  'ETH',
#  'IND',
#  'IDN',
#  'IRN',
#  'ISR',
#  'KAZ',
#  'MYS',
#  'NGA',
#  'PAK',
#  'PRY',
#  'PER',
#  'PHL',
#  'RUS',
#  'SAU',
#  'ZAF',
#  'THA',
#  'UKR',
#  'VNM',
#  'NOR',
#  'CHE',
#  'GBR']

# %%
LIFE = LIFE[LIFE['Country Code'].isin(values2) == True]

# %%
LIFE = LIFE.reset_index().drop(['index'], axis=1)

# %%
#melt LIFE
LIFE = pd.melt(LIFE, id_vars = ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], 
        value_vars = [str(i) for i in range(1990,2014)])
LIFE
# Out:
#       Country Name Country Code                           Indicator Name  \
# 0        Argentina          ARG  Life expectancy at birth, total (years)
# 1        Australia          AUS  Life expectancy at birth, total (years)
# 2           Brazil          BRA  Life expectancy at birth, total (years)
# 3           Canada          CAN  Life expectancy at birth, total (years)
# 4      Switzerland          CHE  Life expectancy at birth, total (years)
# ..             ...          ...                                      ...
# 835         Turkey          TUR  Life expectancy at birth, total (years)
# 836        Ukraine          UKR  Life expectancy at birth, total (years)
# 837  United States          USA  Life expectancy at birth, total (years)
# 838        Vietnam          VNM  Life expectancy at birth, total (years)
# 839   South Africa          ZAF  Life expectancy at birth, total (years)
#
#      Indicator Code variable      value
# 0    SP.DYN.LE00.IN     1990  71.565000
# ...

# %%
LIFE = LIFE.rename({'variable':'Year', 'value':'Life Expectancy'}, axis=1)
LIFE = LIFE.sort_values(by =['Country Name', 'Year']).reset_index().drop(['index', 'Indicator Name', 'Indicator Code'], axis=1)
LIFE
# Out:
#     Country Name Country Code  Year  Life Expectancy
# 0      Argentina          ARG  1990           71.565
# 1      Argentina          ARG  1991           71.790
# 2      Argentina          ARG  1992           72.023
# 3      Argentina          ARG  1993           72.256
# 4      Argentina          ARG  1994           72.489
# ..           ...          ...   ...              ...
# 835      Vietnam          VNM  2009           74.946
# 836      Vietnam          VNM  2010           75.117
# 837      Vietnam          VNM  2011           75.294
# 838      Vietnam          VNM  2012           75.476
# 839      Vietnam          VNM  2013           75.663
#
# [840 rows x 4 columns]

# %%
merged_data = pd.merge(merged_data, LIFE, on=['Country Code', 'Year'], how = 'left')
merged_data
# Out:
#      Country Code Meat_Type  Year  KG_Consumer_Per_Capita  Country Name_x  \
# 0             AUS      BEEF  1990                0.000004       Australia
# 1             AUS      BEEF  1991               27.808401       Australia
# 2             AUS      BEEF  1992               26.278166       Australia
# 3             AUS      BEEF  1993               26.244478       Australia
# 4             AUS      BEEF  1994               25.541244       Australia
# ...           ...       ...   ...                     ...             ...
# 3327          GBR     SHEEP  2009                4.915320  United Kingdom
# 3328          GBR     SHEEP  2010                4.352106  United Kingdom
# 3329          GBR     SHEEP  2011                4.123211  United Kingdom
# 3330          GBR     SHEEP  2012                3.880044  United Kingdom
# 3331          GBR     SHEEP  2013                4.093783  United Kingdom
#
#       Population  GDP per Capita PPP  MtCO2e  Country Name_y  Life Expectancy
# ...

# %%
merged_data = merged_data.drop(['Country Name_y'], axis=1)
merged_data =  merged_data.rename({'Country Name_x': 'Country Name'}, axis=1)
merged_data
# Out:
#      Country Code Meat_Type  Year  KG_Consumer_Per_Capita    Country Name  \
# 0             AUS      BEEF  1990                0.000004       Australia
# 1             AUS      BEEF  1991               27.808401       Australia
# 2             AUS      BEEF  1992               26.278166       Australia
# 3             AUS      BEEF  1993               26.244478       Australia
# 4             AUS      BEEF  1994               25.541244       Australia
# ...           ...       ...   ...                     ...             ...
# 3327          GBR     SHEEP  2009                4.915320  United Kingdom
# 3328          GBR     SHEEP  2010                4.352106  United Kingdom
# 3329          GBR     SHEEP  2011                4.123211  United Kingdom
# 3330          GBR     SHEEP  2012                3.880044  United Kingdom
# 3331          GBR     SHEEP  2013                4.093783  United Kingdom
#
#       Population  GDP per Capita PPP  MtCO2e  Life Expectancy
# ...

# %%
#merged_data.to_csv('/Users/nicholaslandi/Desktop/DataVizCode/meat_merged_emission_life.csv', index=False)

# %%
merged_data.columns
# Out:
# Index(['Country Code', 'Meat_Type', 'Year', 'KG_Consumer_Per_Capita',
#        'Country Name', 'Population', 'GDP per Capita PPP', 'MtCO2e',
#        'Life Expectancy'],
#       dtype='object')

# %%
merged_data[["Population", "GDP per Capita PPP", "Life Expectancy"]].describe()
# Out:
#          Population  GDP per Capita PPP  Life Expectancy
# count  3.332000e+03         3332.000000      3332.000000
# mean   1.330311e+08        15209.509274        71.252681
# std    2.667105e+08        13109.568556         7.641997
# min    3.329800e+06          396.471751        45.841000
# 25%    2.228313e+07         5443.412266        67.570000
# 50%    5.728804e+07        10044.190630        72.259000
# 75%    1.168156e+08        22500.477590        76.994634
# max    1.357380e+09        66961.253100        83.331951

# %%
merged_data["MtCO2e"].describe()
# Out:
# count     3332.00
# unique     828.00
# top         73.74
# freq         8.00
# Name: MtCO2e, dtype: float64

# %% [markdown]
# ## Health and Nutrition Data

# %%
health = pd.read_csv('healthdata.csv')
health.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  \
# 0  % of females ages 15-49 having comprehensive c...  SH.HIV.KNOW.FE.ZS
# 1  % of males ages 15-49 having comprehensive cor...  SH.HIV.KNOW.MA.ZS
# 2  Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 3  Adults (ages 15+) and children (0-14 years) li...        SH.HIV.TOTL
# 4  Adults (ages 15+) and children (ages 0-14) new...     SH.HIV.INCD.TL
#
#          1960        1961        1962        1963        1964        1965  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2  133.555013  134.159119  134.857912  134.504576  134.105211  133.569626
# ...

# %%
health.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', 'Unnamed: 60'],
#       dtype='object')

# %%
health = health.drop(['Country Name', 'Indicator Code',
       '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989','2014', '2015', 'Unnamed: 60'], axis=1)
health.head()
# Out:
#   Country Code                                     Indicator Name       1990  \
# 0          ARB  % of females ages 15-49 having comprehensive c...        NaN
# 1          ARB  % of males ages 15-49 having comprehensive cor...        NaN
# 2          ARB  Adolescent fertility rate (births per 1,000 wo...  69.004413
# 3          ARB  Adults (ages 15+) and children (0-14 years) li...        NaN
# 4          ARB  Adults (ages 15+) and children (ages 0-14) new...        NaN
#
#         1991       1992       1993       1994      1995       1996       1997  \
# 0        NaN        NaN        NaN        NaN       NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN       NaN        NaN        NaN
# 2  67.755992  66.928451  64.948968  62.922778  60.70707  58.596631  56.440128
# 3        NaN        NaN        NaN        NaN       NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN       NaN        NaN        NaN
#
# ...

# %%
values2 = list(merged_data['Country Code'].unique())
values2
# Out:
# ['AUS',
#  'CAN',
#  'JPN',
#  'KOR',
#  'MEX',
#  'NZL',
#  'TUR',
#  'USA',
#  'ARG',
#  'BRA',
#  'CHL',
#  'CHN',
#  'COL',
#  'EGY',
#  'ETH',
#  'IND',
#  'IDN',
#  'IRN',
#  'ISR',
#  'KAZ',
#  'MYS',
#  'NGA',
#  'PAK',
#  'PRY',
#  'PER',
#  'PHL',
#  'RUS',
#  'SAU',
#  'ZAF',
#  'THA',
#  'UKR',
#  'VNM',
#  'NOR',
#  'CHE',
#  'GBR']

# %%
health = health[health['Country Code'].isin(values2) == True]

# %%
health = health.reset_index().drop(['index'], axis=1)
health
# Out:
#       Country Code                                     Indicator Name  \
# 0              ARG  % of females ages 15-49 having comprehensive c...
# 1              ARG  % of males ages 15-49 having comprehensive cor...
# 2              ARG  Adolescent fertility rate (births per 1,000 wo...
# 3              ARG  Adults (ages 15+) and children (0-14 years) li...
# 4              ARG  Adults (ages 15+) and children (ages 0-14) new...
# ...            ...                                                ...
# 12070          VNM  Use of insecticide-treated bed nets (% of unde...
# 12071          VNM  Use of Intermittent Preventive Treatment of ma...
# 12072          VNM  Vitamin A supplementation coverage rate (% of ...
# 12073          VNM           Wanted fertility rate (births per woman)
# 12074          VNM  Women's share of population ages 15+ living wi...
#
#                1990          1991          1992          1993          1994  \
# ...

# %%
health['Country Code']
# Out:
# 0        ARG
# 1        ARG
# 2        ARG
# 3        ARG
# 4        ARG
#         ...
# 12070    VNM
# 12071    VNM
# 12072    VNM
# 12073    VNM
# 12074    VNM
# Name: Country Code, Length: 12075, dtype: object

# %%
print(len(health['Country Code'].unique())) #correct number
# Out:
# 35

# %%
test = health.dropna()
test = test.reset_index().drop(['index'], axis=1)

# %%
test
# Out:
#      Country Code                                     Indicator Name  \
# 0             ARG  Adolescent fertility rate (births per 1,000 wo...
# 1             ARG  Adults (ages 15+) and children (0-14 years) li...
# 2             ARG  Adults (ages 15+) and children (ages 0-14) new...
# 3             ARG                  Adults (ages 15+) living with HIV
# 4             ARG          Adults (ages 15+) newly infected with HIV
# ...           ...                                                ...
# 7095          VNM       Tuberculosis death rate (per 100,000 people)
# 7096          VNM                                   Urban population
# 7097          VNM                      Urban population (% of total)
# 7098          VNM                 Urban population growth (annual %)
# 7099          VNM  Women's share of population ages 15+ living wi...
#
#               1990          1991          1992          1993          1994  \
# ...

# %%
#make year columns rows
#make indicator row columns 
test = pd.melt(test, id_vars = ['Country Code', 'Indicator Name'], 
        value_vars = [str(i) for i in range(1990,2014)])
test
# Out:
#        Country Code                                     Indicator Name  \
# 0               ARG  Adolescent fertility rate (births per 1,000 wo...
# 1               ARG  Adults (ages 15+) and children (0-14 years) li...
# 2               ARG  Adults (ages 15+) and children (ages 0-14) new...
# 3               ARG                  Adults (ages 15+) living with HIV
# 4               ARG          Adults (ages 15+) newly infected with HIV
# ...             ...                                                ...
# 170395          VNM       Tuberculosis death rate (per 100,000 people)
# 170396          VNM                                   Urban population
# 170397          VNM                      Urban population (% of total)
# 170398          VNM                 Urban population growth (annual %)
# 170399          VNM  Women's share of population ages 15+ living wi...
#
#        variable         value
# 0          1990  7.328120e+01
# 1          1990  2.600000e+04
# ...

# %%
test.dtypes
# Out:
# Country Code       object
# Indicator Name     object
# variable           object
# value             float64
# dtype: object

# %%
test = test.pivot_table(index=['Country Code', 'variable'], 
                                  columns='Indicator Name', 
                                  values='value')
test
# Out:
# Indicator Name         AIDS estimated deaths (UNAIDS estimates)  \
# Country Code variable
# ARG          1990                                         500.0
#              1991                                        1000.0
#              1992                                        1000.0
#              1993                                        1300.0
#              1994                                        1600.0
# ...                                                         ...
# ZAF          2009                                      350000.0
#              2010                                      320000.0
#              2011                                      310000.0
#              2012                                      270000.0
#              2013                                      220000.0
#
# Indicator Name         Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# Country Code variable
# ...

# %%
test = pd.DataFrame(test.to_records())
test
# Out:
#     Country Code variable  AIDS estimated deaths (UNAIDS estimates)  \
# 0            ARG     1990                                     500.0
# 1            ARG     1991                                    1000.0
# 2            ARG     1992                                    1000.0
# 3            ARG     1993                                    1300.0
# 4            ARG     1994                                    1600.0
# ..           ...      ...                                       ...
# 835          ZAF     2009                                  350000.0
# 836          ZAF     2010                                  320000.0
# 837          ZAF     2011                                  310000.0
# 838          ZAF     2012                                  270000.0
# 839          ZAF     2013                                  220000.0
#
#      Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                              73.2812
# ...

# %%
test = test.dropna(axis='columns')

# %%
test
# Out:
#     Country Code variable  \
# 0            ARG     1990
# 1            ARG     1991
# 2            ARG     1992
# 3            ARG     1993
# 4            ARG     1994
# ..           ...      ...
# 835          ZAF     2009
# 836          ZAF     2010
# 837          ZAF     2011
# 838          ZAF     2012
# 839          ZAF     2013
#
#      Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                              73.2812
# 1                                              73.2416
# 2                                              73.2020
# 3                                              72.5218
# 4                                              71.8416
# ..                                                 ...
# 835                                            55.8408
# 836                                            54.1812
# 837                                            52.5216
# 838                                            50.8620
# ...

# %%
test = test.rename({'variable':'Year'}, axis=1)
test = test.sort_values(by =['Country Code', 'Year'])
test
# Out:
#     Country Code  Year  \
# 0            ARG  1990
# 1            ARG  1991
# 2            ARG  1992
# 3            ARG  1993
# 4            ARG  1994
# ..           ...   ...
# 835          ZAF  2009
# 836          ZAF  2010
# 837          ZAF  2011
# 838          ZAF  2012
# 839          ZAF  2013
#
#      Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                              73.2812
# 1                                              73.2416
# 2                                              73.2020
# 3                                              72.5218
# 4                                              71.8416
# ..                                                 ...
# 835                                            55.8408
# 836                                            54.1812
# 837                                            52.5216
# 838                                            50.8620
# ...

# %%
test.columns
# Out:
# Index(['Country Code', 'Year',
#        'Adolescent fertility rate (births per 1,000 women ages 15-19)',
#        'Age dependency ratio (% of working-age population)',
#        'Age dependency ratio, old', 'Age dependency ratio, young',
#        'Age population, age 0, female, interpolated',
#        'Age population, age 0, male, interpolated',
#        'Age population, age 01, female, interpolated',
#        'Age population, age 01, male, interpolated',
#        ...
#        'Prevalence of tuberculosis (per 100,000 population)',
#        'Rural population', 'Rural population (% of total population)',
#        'Rural population growth (annual %)',
#        'Survival to age 65, female (% of cohort)',
#        'Survival to age 65, male (% of cohort)',
#        'Tuberculosis death rate (per 100,000 people)', 'Urban population',
#        'Urban population (% of total)', 'Urban population growth (annual %)'],
#       dtype='object', length=179)

# %%
test_clean = test[['Country Code', 'Year', 'Adolescent fertility rate (births per 1,000 women ages 15-19)', 'Fertility rate, total (births per woman)',
                  'Number of infant deaths', 'Number of maternal deaths', 'Prevalence of tuberculosis (per 100,000 population)',
                  'Rural population', 'Rural population (% of total population)', 'Rural population growth (annual %)',
                  'Urban population', 'Urban population (% of total)', 'Urban population growth (annual %)']]
test_clean
# Out:
#     Country Code  Year  \
# 0            ARG  1990
# 1            ARG  1991
# 2            ARG  1992
# 3            ARG  1993
# 4            ARG  1994
# ..           ...   ...
# 835          ZAF  2009
# 836          ZAF  2010
# 837          ZAF  2011
# 838          ZAF  2012
# 839          ZAF  2013
#
#      Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                              73.2812
# 1                                              73.2416
# 2                                              73.2020
# 3                                              72.5218
# 4                                              71.8416
# ..                                                 ...
# 835                                            55.8408
# 836                                            54.1812
# 837                                            52.5216
# 838                                            50.8620
# ...

# %%
test_clean.dtypes
# Out:
# Country Code                                                      object
# Year                                                              object
# Adolescent fertility rate (births per 1,000 women ages 15-19)    float64
# Fertility rate, total (births per woman)                         float64
# Number of infant deaths                                          float64
# Number of maternal deaths                                        float64
# Prevalence of tuberculosis (per 100,000 population)              float64
# Rural population                                                 float64
# Rural population (% of total population)                         float64
# Rural population growth (annual %)                               float64
# Urban population                                                 float64
# Urban population (% of total)                                    float64
# Urban population growth (annual %)                               float64
# dtype: object

# %%
merged_data = pd.merge(merged_data, test_clean, on=['Country Code', 'Year'], how = 'left')
merged_data
# Out:
#      Country Code Meat_Type  Year  KG_Consumer_Per_Capita    Country Name  \
# 0             AUS      BEEF  1990                0.000004       Australia
# 1             AUS      BEEF  1991               27.808401       Australia
# 2             AUS      BEEF  1992               26.278166       Australia
# 3             AUS      BEEF  1993               26.244478       Australia
# 4             AUS      BEEF  1994               25.541244       Australia
# ...           ...       ...   ...                     ...             ...
# 3327          GBR     SHEEP  2009                4.915320  United Kingdom
# 3328          GBR     SHEEP  2010                4.352106  United Kingdom
# 3329          GBR     SHEEP  2011                4.123211  United Kingdom
# 3330          GBR     SHEEP  2012                3.880044  United Kingdom
# 3331          GBR     SHEEP  2013                4.093783  United Kingdom
#
#       Population  GDP per Capita PPP  MtCO2e  Life Expectancy  \
# ...

# %%
#merged_data.to_csv('/Users/nicholaslandi/Desktop/DataVizCode/final_dataset.csv', index=False)

# %%
#merged_data['Adolescent fertility rate (births per 1,000 women ages 15-19)'].describe()

# %%
#merged_data['Number of maternal deaths'].describe()

# %%
#need to convert some of the numeric variables to categorical

# %%
#merged_data['Rural population (% of total population)'].describe()

# %%
#merged_data['Rural population growth (annual %)'].describe()

# %%
merged_data['Urban population (% of total)'].describe()
# Out:
# count    3332.000000
# mean       63.651242
# std        20.823457
# min        13.370000
# 25%        46.732000
# 50%        71.834000
# 75%        79.757000
# max        92.491000
# Name: Urban population (% of total), dtype: float64

# %%
merged_data['Urban population growth (annual %)'].describe()
# Out:
# count    3332.000000
# mean        2.087039
# std         1.330037
# min        -1.714699
# 25%         1.227707
# 50%         1.915582
# 75%         2.995269
# max         6.132051
# Name: Urban population growth (annual %), dtype: float64

# %%
#merged_data['Urban population growth (annual %)'].value_counts()

# %%
merged_data['percent_urban_population_bins'] = pd.cut(merged_data['Urban population (% of total)']
                                                      , bins=[0,20,40,60,80,100]
                                                      , labels=("20 or smaller", "20-40", "40-60", "60-80", "80 or greater"))

# %%
merged_data.head()
# Out:
#   Country Code Meat_Type  Year  KG_Consumer_Per_Capita Country Name  \
# 0          AUS      BEEF  1990                0.000004    Australia
# 1          AUS      BEEF  1991               27.808401    Australia
# 2          AUS      BEEF  1992               26.278166    Australia
# 3          AUS      BEEF  1993               26.244478    Australia
# 4          AUS      BEEF  1994               25.541244    Australia
#
#    Population  GDP per Capita PPP  MtCO2e  Life Expectancy  \
# 0  17065100.0         17329.70661  558.21        76.994634
# 1  17284000.0         17790.98014  558.13        77.275610
# 2  17495000.0         18189.37874   560.3        77.378049
# 3  17667000.0         19131.84187  559.98        77.878049
# 4  17855000.0         20064.45901  563.06        77.878049
#
#    Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                            20.9650
# 1                                            20.9200
# ...

# %%
merged_data['percent_urban_population_bins'].value_counts()
# Out:
# 60-80            1280
# 80 or greater     792
# 40-60             660
# 20-40             516
# 20 or smaller      84
# Name: percent_urban_population_bins, dtype: int64

# %%
merged_data['percent_urban_population_annual_growth_bins'] = pd.cut(merged_data['Urban population growth (annual %)']
                                                      , bins=[-5,0,2,10]
                                                      , labels=("0% or less", "0 to 2%", "2% or more"))

# %%
merged_data['percent_urban_population_annual_growth_bins'].value_counts()
# Out:
# 0 to 2%       1584
# 2% or more    1572
# 0% or less     176
# Name: percent_urban_population_annual_growth_bins, dtype: int64

# %%
#merged_data.to_csv('/Users/nicholaslandi/Desktop/DataVizCode/final_dataset.csv', index=False)

# %%
merged_data.columns
# Out:
# Index(['Country Code', 'Meat_Type', 'Year', 'KG_Consumer_Per_Capita',
#        'Country Name', 'Population', 'GDP per Capita PPP', 'MtCO2e',
#        'Life Expectancy',
#        'Adolescent fertility rate (births per 1,000 women ages 15-19)',
#        'Fertility rate, total (births per woman)', 'Number of infant deaths',
#        'Number of maternal deaths',
#        'Prevalence of tuberculosis (per 100,000 population)',
#        'Rural population', 'Rural population (% of total population)',
#        'Rural population growth (annual %)', 'Urban population',
#        'Urban population (% of total)', 'Urban population growth (annual %)',
#        'percent_urban_population_bins',
#        'percent_urban_population_annual_growth_bins'],
#       dtype='object')

# %%
merged_data['KG_Consumer_Per_Capita'].describe()
# Out:
# count    3.332000e+03
# mean     9.859388e+00
# std      1.072217e+01
# min      7.505680e-08
# 25%      1.370334e+00
# 50%      5.961535e+00
# 75%      1.492359e+01
# max      6.607637e+01
# Name: KG_Consumer_Per_Capita, dtype: float64

# %%
merged_data['Life Expectancy'].describe()
# Out:
# count    3332.000000
# mean       71.252681
# std         7.641997
# min        45.841000
# 25%        67.570000
# 50%        72.259000
# 75%        76.994634
# max        83.331951
# Name: Life Expectancy, dtype: float64

# %%
merged_data['GDP per Capita PPP'].describe()
# Out:
# count     3332.000000
# mean     15209.509274
# std      13109.568556
# min        396.471751
# 25%       5443.412266
# 50%      10044.190630
# 75%      22500.477590
# max      66961.253100
# Name: GDP per Capita PPP, dtype: float64

# %%
merged_data
# Out:
#      Country Code Meat_Type  Year  KG_Consumer_Per_Capita    Country Name  \
# 0             AUS      BEEF  1990                0.000004       Australia
# 1             AUS      BEEF  1991               27.808401       Australia
# 2             AUS      BEEF  1992               26.278166       Australia
# 3             AUS      BEEF  1993               26.244478       Australia
# 4             AUS      BEEF  1994               25.541244       Australia
# ...           ...       ...   ...                     ...             ...
# 3327          GBR     SHEEP  2009                4.915320  United Kingdom
# 3328          GBR     SHEEP  2010                4.352106  United Kingdom
# 3329          GBR     SHEEP  2011                4.123211  United Kingdom
# 3330          GBR     SHEEP  2012                3.880044  United Kingdom
# 3331          GBR     SHEEP  2013                4.093783  United Kingdom
#
#       Population  GDP per Capita PPP  MtCO2e  Life Expectancy  \
# ...

# %%
kg_median_year = merged_data.groupby('Year').agg({'KG_Consumer_Per_Capita': np.median}).reset_index()
kg_median_year
# Out:
#     Year  KG_Consumer_Per_Capita
# 0   1990                3.951289
# 1   1991                4.178986
# 2   1992                5.284320
# 3   1993                5.009126
# 4   1994                5.005571
# 5   1995                5.551360
# 6   1996                5.642262
# 7   1997                5.666852
# 8   1998                5.659824
# 9   1999                5.515951
# 10  2000                5.835717
# 11  2001                6.152428
# 12  2002                6.454882
# 13  2003                6.135199
# 14  2004                6.579470
# 15  2005                6.340222
# 16  2006                6.631407
# 17  2007                6.691626
# 18  2008                7.248869
# 19  2009                6.740250
# 20  2010                6.770376
# 21  2011                7.017861
# 22  2012                7.171630
# 23  2013                7.879610

# %%
GDP_median_year = merged_data.groupby('Year').agg({'GDP per Capita PPP': np.median}).reset_index()
GDP_median_year
# Out:
#     Year  GDP per Capita PPP
# 0   1990         6604.940832
# 1   1991         6901.664012
# 2   1992         6890.441285
# 3   1993         7022.865021
# 4   1994         6568.780825
# 5   1995         7351.828808
# 6   1996         8011.571183
# 7   1997         8594.561343
# 8   1998         8588.358096
# 9   1999         8624.437256
# 10  2000         9073.976905
# 11  2001         9215.131989
# 12  2002         9581.992836
# 13  2003         9747.941038
# 14  2004        10860.058740
# 15  2005        11887.863950
# 16  2006        13808.177620
# 17  2007        14849.325290
# 18  2008        16053.803790
# 19  2009        15489.871920
# 20  2010        17425.861360
# 21  2011        18400.906290
# 22  2012        17162.927520
# 23  2013        17373.897020

# %%
life_median_year = merged_data.groupby('Year').agg({'Life Expectancy': np.median}).reset_index()
life_median_year
# Out:
#     Year  Life Expectancy
# 0   1990          69.7715
# 1   1991          69.8700
# 2   1992          69.7045
# 3   1993          69.7500
# 4   1994          69.9350
# 5   1995          70.1560
# 6   1996          70.2140
# 7   1997          70.2660
# 8   1998          70.4160
# 9   1999          70.7270
# 10  2000          71.0190
# 11  2001          71.2930
# 12  2002          71.5560
# 13  2003          71.8130
# 14  2004          72.1460
# 15  2005          72.4810
# 16  2006          72.8660
# 17  2007          73.2190
# 18  2008          73.3310
# 19  2009          73.6170
# 20  2010          73.9320
# 21  2011          74.3750
# 22  2012          74.6060
# 23  2013          74.7970

# %%
merged_data['MtCO2e'] = merged_data['MtCO2e'].astype(float)
merged_data.dtypes
# Out:
# Country Code                                                       object
# Meat_Type                                                          object
# Year                                                               object
# KG_Consumer_Per_Capita                                            float64
# Country Name                                                       object
# Population                                                        float64
# GDP per Capita PPP                                                float64
# MtCO2e                                                            float64
# Life Expectancy                                                   float64
# Adolescent fertility rate (births per 1,000 women ages 15-19)     float64
# Fertility rate, total (births per woman)                          float64
# Number of infant deaths                                           float64
# Number of maternal deaths                                         float64
# ...

# %%
C02_median_year = merged_data.groupby('Year').agg({'MtCO2e': np.median}).reset_index()
C02_median_year
# Out:
#     Year   MtCO2e
# 0   1990  228.810
# 1   1991  239.455
# 2   1992  283.190
# 3   1993  272.120
# 4   1994  252.510
# 5   1995  255.070
# 6   1996  269.710
# 7   1997  266.820
# 8   1998  271.900
# 9   1999  267.240
# 10  2000  278.870
# 11  2001  270.240
# 12  2002  288.900
# 13  2003  298.200
# 14  2004  322.760
# 15  2005  336.400
# 16  2006  332.300
# 17  2007  357.030
# 18  2008  368.360
# 19  2009  327.370
# 20  2010  345.370
# 21  2011  363.650
# 22  2012  364.850
# 23  2013  353.900

# %%
pop_median_year = merged_data.groupby('Year').agg({'Population': np.median}).reset_index()
pop_median_year
# Out:
#     Year  Population
# 0   1990  55081900.5
# 1   1991  56067740.0
# 2   1992  53980700.0
# 3   1993  53477944.0
# 4   1994  55366517.0
# 5   1995  57237226.0
# 6   1996  58166950.0
# 7   1997  58316954.0
# 8   1998  58487141.0
# 9   1999  58682466.0
# 10  2000  58892514.0
# 11  2001  59119673.0
# 12  2002  59370479.0
# 13  2003  59647577.0
# 14  2004  59987905.0
# 15  2005  60401206.0
# 16  2006  60846820.0
# 17  2007  61322463.0
# 18  2008  61806995.0
# 19  2009  62276270.0
# 20  2010  62766365.0
# 21  2011  63258918.0
# 22  2012  63700300.0
# 23  2013  64106779.0

# %%
merged_data.loc[0, 'Year']
# Out:
# '1990'

# %%
kg_median_year
# Out:
#     Year  KG_Consumer_Per_Capita
# 0   1990                3.951289
# 1   1991                4.178986
# 2   1992                5.284320
# 3   1993                5.009126
# 4   1994                5.005571
# 5   1995                5.551360
# 6   1996                5.642262
# 7   1997                5.666852
# 8   1998                5.659824
# 9   1999                5.515951
# 10  2000                5.835717
# 11  2001                6.152428
# 12  2002                6.454882
# 13  2003                6.135199
# 14  2004                6.579470
# 15  2005                6.340222
# 16  2006                6.631407
# 17  2007                6.691626
# 18  2008                7.248869
# 19  2009                6.740250
# 20  2010                6.770376
# 21  2011                7.017861
# 22  2012                7.171630
# 23  2013                7.879610

# %%
merged_data = pd.merge(merged_data, kg_median_year, on=['Year'], how = 'left')

# %%
#test_merge.to_csv('/Users/nicholaslandi/Desktop/DataVizCode/test.csv', index=False)

# %%
merged_data = pd.merge(merged_data, GDP_median_year , on=['Year'], how = 'left')

# %%
merged_data = pd.merge(merged_data, life_median_year , on=['Year'], how = 'left')

# %%
merged_data = pd.merge(merged_data, C02_median_year , on=['Year'], how = 'left')

# %%
merged_data = pd.merge(merged_data, pop_median_year  , on=['Year'], how = 'left')

# %%
#merged_data.to_csv('/Users/nicholaslandi/Desktop/DataVizCode/final_dataset.csv', index=False)

# %%
merged_data
# Out:
#      Country Code Meat_Type  Year  KG_Consumer_Per_Capita_x    Country Name  \
# 0             AUS      BEEF  1990                  0.000004       Australia
# 1             AUS      BEEF  1991                 27.808401       Australia
# 2             AUS      BEEF  1992                 26.278166       Australia
# 3             AUS      BEEF  1993                 26.244478       Australia
# 4             AUS      BEEF  1994                 25.541244       Australia
# ...           ...       ...   ...                       ...             ...
# 3327          GBR     SHEEP  2009                  4.915320  United Kingdom
# 3328          GBR     SHEEP  2010                  4.352106  United Kingdom
# 3329          GBR     SHEEP  2011                  4.123211  United Kingdom
# 3330          GBR     SHEEP  2012                  3.880044  United Kingdom
# 3331          GBR     SHEEP  2013                  4.093783  United Kingdom
#
# ...

# %%
merged_data.columns
# Out:
# Index(['Country Code', 'Meat_Type', 'Year', 'KG_Consumer_Per_Capita_x',
#        'Country Name', 'Population_x', 'GDP per Capita PPP_x', 'MtCO2e_x',
#        'Life Expectancy_x',
#        'Adolescent fertility rate (births per 1,000 women ages 15-19)',
#        'Fertility rate, total (births per woman)', 'Number of infant deaths',
#        'Number of maternal deaths',
#        'Prevalence of tuberculosis (per 100,000 population)',
#        'Rural population', 'Rural population (% of total population)',
#        'Rural population growth (annual %)', 'Urban population',
#        'Urban population (% of total)', 'Urban population growth (annual %)',
#        'percent_urban_population_bins',
#        'percent_urban_population_annual_growth_bins',
#        'KG_Consumer_Per_Capita_y', 'GDP per Capita PPP_y', 'Life Expectancy_y',
#        'MtCO2e_y', 'Population_y'],
#       dtype='object')

# %%
merged_data = merged_data.rename({'KG_Consumer_Per_Capita_x':'KG_Consumer_Per_Capita'
                                  , 'Population_x':'Population', 
                                  'GDP per Capita PPP_x':'GDP per Capita PPP',
                                 'MtCO2e_x': 'MtCO2e',
                                 'Life Expectancy_x': 'Life Expectancy',
                                 'KG_Consumer_Per_Capita_y': 'Median_KG_Year',
                                 'GDP per Capita PPP_y': 'Median_GDP_Year', 
                                 'Life Expectancy_y': 'Median_Life_Year',
                                 'MtCO2e_y': 'Median_MtCO2e_Year',
                                'Population_y': 'Median_Population_Year'}, axis=1)

# %%
#merged_data.to_csv('/Users/nicholaslandi/Desktop/DataVizCode/final_dataset.csv', index=False)

# %%
merged_data['Population'].describe()
# Out:
# count    3.332000e+03
# mean     1.330311e+08
# std      2.667105e+08
# min      3.329800e+06
# 25%      2.228313e+07
# 50%      5.728804e+07
# 75%      1.168156e+08
# max      1.357380e+09
# Name: Population, dtype: float64

# %%
1.357380e+09
# Out:
# 1357380000.0

# %%
merged_data['GDP per Capita PPP'].describe()
# Out:
# count     3332.000000
# mean     15209.509274
# std      13109.568556
# min        396.471751
# 25%       5443.412266
# 50%      10044.190630
# 75%      22500.477590
# max      66961.253100
# Name: GDP per Capita PPP, dtype: float64

# %%
merged_data['MtCO2e'].describe()
# Out:
# count     3332.000000
# mean       803.965978
# std       1461.380679
# min          1.170000
# 25%        147.110000
# 50%        300.140000
# 75%        669.830000
# max      11144.760000
# Name: MtCO2e, dtype: float64

# %%
merged_data['scaled_MtCO2e'] = merged_data['MtCO2e']/120

# %%
merged_data['scaled GDP per Capita PPP'] = merged_data['GDP per Capita PPP']/700

# %%
merged_data['scaled_Population'] = merged_data['Population']/14000000

# %%
merged_data['scaled_Population'].describe()
# Out:
# count    3332.000000
# mean        9.502219
# std        19.050753
# min         0.237843
# 25%         1.591652
# 50%         4.092003
# 75%         8.343972
# max        96.955714
# Name: scaled_Population, dtype: float64

# %%
merged_data['scaled GDP per Capita PPP'].describe()
# Out:
# count    3332.000000
# mean       21.727870
# std        18.727955
# min         0.566388
# 25%         7.776303
# 50%        14.348844
# 75%        32.143539
# max        95.658933
# Name: scaled GDP per Capita PPP, dtype: float64

# %%
merged_data['scaled_MtCO2e'].describe()
# Out:
# count    3332.000000
# mean        6.699716
# std        12.178172
# min         0.009750
# 25%         1.225917
# 50%         2.501167
# 75%         5.581917
# max        92.873000
# Name: scaled_MtCO2e, dtype: float64

# %%
scaled_co2_median_year = merged_data.groupby('Year').agg({'scaled_MtCO2e': np.median}).reset_index()
scaled_co2_median_year
# Out:
#     Year  scaled_MtCO2e
# 0   1990       1.906750
# 1   1991       1.995458
# 2   1992       2.359917
# 3   1993       2.267667
# 4   1994       2.104250
# 5   1995       2.125583
# 6   1996       2.247583
# 7   1997       2.223500
# 8   1998       2.265833
# 9   1999       2.227000
# 10  2000       2.323917
# 11  2001       2.252000
# 12  2002       2.407500
# 13  2003       2.485000
# 14  2004       2.689667
# 15  2005       2.803333
# 16  2006       2.769167
# 17  2007       2.975250
# 18  2008       3.069667
# 19  2009       2.728083
# 20  2010       2.878083
# 21  2011       3.030417
# 22  2012       3.040417
# 23  2013       2.949167

# %%
scaled_GDP_median_year = merged_data.groupby('Year').agg({'scaled GDP per Capita PPP': np.median}).reset_index()
scaled_GDP_median_year
# Out:
#     Year  scaled GDP per Capita PPP
# 0   1990                   9.435630
# 1   1991                   9.859520
# 2   1992                   9.843488
# 3   1993                  10.032664
# 4   1994                   9.383973
# 5   1995                  10.502613
# 6   1996                  11.445102
# 7   1997                  12.277945
# 8   1998                  12.269083
# 9   1999                  12.320625
# 10  2000                  12.962824
# 11  2001                  13.164474
# 12  2002                  13.688561
# 13  2003                  13.925630
# 14  2004                  15.514370
# 15  2005                  16.982663
# 16  2006                  19.725968
# 17  2007                  21.213322
# 18  2008                  22.934005
# 19  2009                  22.128388
# 20  2010                  24.894088
# 21  2011                  26.287009
# 22  2012                  24.518468
# 23  2013                  24.819853

# %%
scaled_pop_median_year = merged_data.groupby('Year').agg({'scaled_Population': np.median}).reset_index()
scaled_pop_median_year
# Out:
#     Year  scaled_Population
# 0   1990           3.934421
# 1   1991           4.004839
# 2   1992           3.855764
# 3   1993           3.819853
# 4   1994           3.954751
# 5   1995           4.088373
# 6   1996           4.154782
# 7   1997           4.165497
# 8   1998           4.177653
# 9   1999           4.191605
# 10  2000           4.206608
# 11  2001           4.222834
# 12  2002           4.240748
# 13  2003           4.260541
# 14  2004           4.284850
# 15  2005           4.314372
# 16  2006           4.346201
# 17  2007           4.380176
# 18  2008           4.414785
# 19  2009           4.448305
# 20  2010           4.483312
# 21  2011           4.518494
# 22  2012           4.550021
# 23  2013           4.579056

# %%
#print(merged_data['KG_Consumer_Per_Capita'].describe())
#print(merged_data['Life Expectancy'].describe())

# %%
merged_data = pd.merge(merged_data, scaled_co2_median_year , on=['Year'], how = 'left')

# %%
merged_data = pd.merge(merged_data, scaled_GDP_median_year , on=['Year'], how = 'left')

# %%
merged_data = pd.merge(merged_data, scaled_pop_median_year , on=['Year'], how = 'left')

# %%
merged_data = merged_data.rename({'scaled_MtCO2e_x':'scaled_MtCO2e'
                                  , 'scaled GDP per Capita PPP_x':'scaled_GDP_per_Capita_PPP', 
                                  'scaled_Population_x':'scaled_Population',
                                 'scaled_MtCO2e_y': 'scaled_median_MtCO2e_year',
                                 'scaled GDP per Capita PPP_y': 'scaled_median_GDP_per_Capita_PPP_year',
                                 'scaled_Population_y': 'scaled_median_Population_year'}, axis=1)

# %%
merged_data
# Out:
#      Country Code Meat_Type  Year  KG_Consumer_Per_Capita    Country Name  \
# 0             AUS      BEEF  1990                0.000004       Australia
# 1             AUS      BEEF  1991               27.808401       Australia
# 2             AUS      BEEF  1992               26.278166       Australia
# 3             AUS      BEEF  1993               26.244478       Australia
# 4             AUS      BEEF  1994               25.541244       Australia
# ...           ...       ...   ...                     ...             ...
# 3327          GBR     SHEEP  2009                4.915320  United Kingdom
# 3328          GBR     SHEEP  2010                4.352106  United Kingdom
# 3329          GBR     SHEEP  2011                4.123211  United Kingdom
# 3330          GBR     SHEEP  2012                3.880044  United Kingdom
# 3331          GBR     SHEEP  2013                4.093783  United Kingdom
#
#       Population  GDP per Capita PPP  MtCO2e  Life Expectancy  \
# ...

# %%
#merged_data.to_csv('/Users/nicholaslandi/Desktop/DataVizCode/final_dataset.csv', index=False)

# %%
merged_data[merged_data['Year'] == '2007']['Median_GDP_Year']
# Out:
# 17      14849.32529
# 41      14849.32529
# 65      14849.32529
# 89      14849.32529
# 113     14849.32529
#            ...
# 3229    14849.32529
# 3253    14849.32529
# 3277    14849.32529
# 3301    14849.32529
# 3325    14849.32529
# Name: Median_GDP_Year, Length: 140, dtype: float64

# %%
merged_data[merged_data['Year'] == '2007']['Median_KG_Year'].describe()
# Out:
# count    1.400000e+02
# mean     6.691626e+00
# std      1.069641e-14
# min      6.691626e+00
# 25%      6.691626e+00
# 50%      6.691626e+00
# 75%      6.691626e+00
# max      6.691626e+00
# Name: Median_KG_Year, dtype: float64

# %%
#merged_data[(merged_data['Year'] == '2007') & (merged_data['Country Name'] =='Nigeria')]
